# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskriti111-j/Data-Analysis/blob/main/EDA_using_univariate_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/covid_related_disease_data.csv')

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender  ...     Occupation Smoking_Status   BMI
# 0           1   69    Male  ...     Healthcare          Never  27.7
# 1           2   38    Male  ...     Healthcare          Never  21.9
# 2           3   41  Female  ...     Unemployed          Never  22.7
# 3           4   81  Female  ...  Office Worker          Never  27.7
# 4           5   50  Female  ...        Student          Never  11.9
#
# [5 rows x 26 columns]

# %% [markdown]
# Categorical Data

# %% [markdown]
# 1.Countplot

# %%
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.countplot(df['COVID_Strain'])
# Out:
# <Axes: xlabel='count', ylabel='COVID_Strain'>

# %%
df['Smoking_Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Smoking_Status'>

# %% [markdown]
# 2. Piechart

# %%
df['COVID_Strain'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Occupation'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Vaccine_Type'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Reinfection'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Numerical Data

# %% [markdown]
# 1.Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=10)
# Out:
# (array([311., 297., 302., 291., 281., 276., 272., 320., 299., 351.]),
#  array([18. , 25.1, 32.2, 39.3, 46.4, 53.5, 60.6, 67.7, 74.8, 81.9, 89. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 2.Distplot

# %%
sns.distplot(df['Age'])
# Out:
# <ipython-input-21-0fafe04ea3f6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# Finding skewness of the age that is getting more affected by covid

# %%
df['Age'].skew()
# Out:
# np.float64(-0.015164478848176254)

# %% [markdown]
# skewness in bmi

# %%
df['BMI'].skew()
# Out:
# np.float64(-0.02963944534739663)

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>
